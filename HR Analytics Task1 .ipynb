# %% [markdown]
# # HR Analytics

# %% [markdown]
# ## Import Libraries and Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel(r"C:\Users\reeba\Downloads\Train_Data.xlsx")

# %% [markdown]
# ## Data Exploration

# %%
df.head()   #top 5 rows
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0        23798  city_149                   0.689   Male
# 1        29166   city_83                   0.923   Male
# 2           46   city_16                   0.910    NaN
# 3        18527   city_64                   0.666   Male
# 4        21751  city_100                   0.887    NaN
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1  Has relevent experience       no_enrollment        Graduate
# 2  Has relevent experience       no_enrollment        Graduate
# 3  Has relevent experience       no_enrollment        Graduate
# 4   No relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM          3      100-500         Pvt Ltd            1
# 1             STEM         14          <10  Funded Startup            1
# 2             STEM          6        50-99   Public Sector            2
# 3             STEM         14        50-99         Pvt Ltd            1
# 4             STEM          8          NaN             NaN            2
#
#    training_hours  target
# 0             106       0
# 1              69       0
# 2               4       0
# 3              26       0
# 4              88       1

# %%
df.tail()   #last 5 rows
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 18354        25366  city_103                   0.920    Male
# 18355        25545  city_160                   0.920    Male
# 18356        11514  city_114                   0.926    Male
# 18357         1689   city_75                   0.939    Male
# 18358         5995  city_105                   0.794  Female
#
#            relevent_experience enrolled_university education_level  \
# 18354  Has relevent experience    Full time course        Graduate
# 18355   No relevent experience       no_enrollment        Graduate
# 18356  Has relevent experience       no_enrollment         Masters
# 18357  Has relevent experience       no_enrollment        Graduate
# 18358  Has relevent experience       no_enrollment        Graduate
#
#       major_discipline experience         company_size company_type  \
# 18354             STEM          5                  <10      Pvt Ltd
# 18355       Humanities         15                50-99      Pvt Ltd
# 18356             STEM         11                50-99      Pvt Ltd
# 18357             STEM        >20  1949-10-01 00:00:00      Pvt Ltd
# 18358             STEM        >20              100-500      Pvt Ltd
#
#       last_new_job  training_hours  target
# 18354            1              71       0
# 18355            1             160       0
# 18356            3              18       0
# 18357            3              41       0
# 18358            2              84       0

# %%
df.shape   #number of rows and columns
# Out:
# (18359, 14)

# %%
df.info()  #column names and datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18359 entries, 0 to 18358
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             18359 non-null  int64
#  1   city                    18359 non-null  object
#  2   city_development_index  18359 non-null  float64
#  3   gender                  14261 non-null  object
#  4   relevent_experience     18359 non-null  object
#  5   enrolled_university     18017 non-null  object
#  6   education_level         17902 non-null  object
#  7   major_discipline        15521 non-null  object
#  8   experience              18300 non-null  object
#  9   company_size            13580 non-null  object
#  10  company_type            13320 non-null  object
#  11  last_new_job            17992 non-null  object
#  12  training_hours          18359 non-null  int64
#  13  target                  18359 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 2.0+ MB

# %%
df.columns   #all column names
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'last_new_job', 'training_hours', 'target'],
#       dtype='object')

# %%
df.dtypes   #datatypes of all columns
# Out:
# enrollee_id                 int64
# city                       object
# city_development_index    float64
# gender                     object
# relevent_experience        object
# enrolled_university        object
# education_level            object
# major_discipline           object
# experience                 object
# company_size               object
# company_type               object
# last_new_job               object
# training_hours              int64
# target                      int64
# dtype: object

# %% [markdown]
# ## Data Cleaning and Manipulation

# %%
df1=df.copy()   # making a copy of the file
df1
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 0            23798  city_149                   0.689    Male
# 1            29166   city_83                   0.923    Male
# 2               46   city_16                   0.910     NaN
# 3            18527   city_64                   0.666    Male
# 4            21751  city_100                   0.887     NaN
# ...            ...       ...                     ...     ...
# 18354        25366  city_103                   0.920    Male
# 18355        25545  city_160                   0.920    Male
# 18356        11514  city_114                   0.926    Male
# 18357         1689   city_75                   0.939    Male
# 18358         5995  city_105                   0.794  Female
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1      Has relevent experience       no_enrollment        Graduate
# 2      Has relevent experience       no_enrollment        Graduate
# 3      Has relevent experience       no_enrollment        Graduate
# 4       No relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 18354  Has relevent experience    Full time course        Graduate
# 18355   No relevent experience       no_enrollment        Graduate
# 18356  Has relevent experience       no_enrollment         Masters
# 18357  Has relevent experience       no_enrollment        Graduate
# 18358  Has relevent experience       no_enrollment        Graduate
#
#       major_discipline experience         company_size    company_type  \
# 0                 STEM          3              100-500         Pvt Ltd
# 1                 STEM         14                  <10  Funded Startup
# 2                 STEM          6                50-99   Public Sector
# 3                 STEM         14                50-99         Pvt Ltd
# 4                 STEM          8                  NaN             NaN
# ...                ...        ...                  ...             ...
# 18354             STEM          5                  <10         Pvt Ltd
# 18355       Humanities         15                50-99         Pvt Ltd
# 18356             STEM         11                50-99         Pvt Ltd
# 18357             STEM        >20  1949-10-01 00:00:00         Pvt Ltd
# 18358             STEM        >20              100-500         Pvt Ltd
#
#       last_new_job  training_hours  target
# 0                1             106       0
# 1                1              69       0
# 2                2               4       0
# 3                1              26       0
# 4                2              88       1
# ...            ...             ...     ...
# 18354            1              71       0
# 18355            1             160       0
# 18356            3              18       0
# 18357            3              41       0
# 18358            2              84       0
#
# [18359 rows x 14 columns]

# %% [markdown]
# ### Check for Duplicates

# %%
df1[df1.duplicated()]   #checking for duplicated records
# Out:
# Empty DataFrame
# Columns: [enrollee_id, city, city_development_index, gender, relevent_experience, enrolled_university, education_level, major_discipline, experience, company_size, company_type, last_new_job, training_hours, target]
# Index: []

# %%
# No duplicates found

# %% [markdown]
# ### Check for Null Values

# %%
df1.isnull().sum()   #number of null values in each field
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                    4098
# relevent_experience          0
# enrolled_university        342
# education_level            457
# major_discipline          2838
# experience                  59
# company_size              4779
# company_type              5039
# last_new_job               367
# training_hours               0
# target                       0
# dtype: int64

# %%
## no null values in the numerical fields

# %%
4098/18359 *100  #percentage of null values in Gender field
# Out:
# 22.321477204640775

# %%
2838/18359 *100   #percentage of null values in major_discipline  field
# Out:
# 15.458358298382265

# %%
4779/18359 *100   #percentage of null values in company_size  field
# Out:
# 26.03082956588049

# %%
5039/18359 *100   #percentage of null values in company_type field
# Out:
# 27.447028705267172

# %%
## No columns to be dropped

# %%
df1=df1.dropna()   ## dropping records with atleast one null value
df1.shape
# Out:
# (9287, 14)

# %% [markdown]
# ### Check for Inconsistent Data

# %%
# Check numerical fields

# %%
for i in df1.describe(exclude=object):
    print(i)
    print(df1[i].value_counts())
    print('_'*100)
# Out:
# enrollee_id
# 23798    1
# 9532     1
# 12177    1
# 1859     1
# 30117    1
#         ..
# 8533     1
# 8311     1
# 3187     1
# 16749    1
# 5995     1
# Name: enrollee_id, Length: 9287, dtype: int64
# ____________________________________________________________________________________________________
# city_development_index
# 0.920    3143
# 0.910     927
# 0.926     722
# 0.624     689
# 0.897     322
#          ...
# 0.516       1
# 0.518       1
# 0.745       1
# 0.645       1
# 0.625       1
# Name: city_development_index, Length: 90, dtype: int64
# ____________________________________________________________________________________________________
# training_hours
# 28     161
# 20     146
# 26     144
# 18     141
# 22     140
#       ...
# 310      2
# 302      2
# 234      2
# 244      2
# 236      2
# Name: training_hours, Length: 241, dtype: int64
# ____________________________________________________________________________________________________
# target
# 0    8296
# 1     991
# Name: target, dtype: int64
# ____________________________________________________________________________________________________

# %%
df1.describe(include=object)
# Out:
#             city gender      relevent_experience enrolled_university  \
# count       9287   9287                     9287                9287
# unique       115      3                        2                   3
# top     city_103   Male  Has relevent experience       no_enrollment
# freq        2685   8366                     8133                7905
#
#        education_level major_discipline experience company_size company_type  \
# count             9287             9287       9287         9287         9287
# unique               3                6         22            8            6
# top           Graduate             STEM        >20        50-99      Pvt Ltd
# freq              6418             8228       2107         2047         7018
#
#         last_new_job
# count           9287
# unique             6
# top                1
# freq            3897

# %%
# Checking categorical fields

# %%
for i in df1.describe(include=object):
    print (i)
    print(df1[i].value_counts())
    print ('_'*100)
# Out:
# city
# city_103    2685
# city_16      927
# city_114     722
# city_21      689
# city_160     458
#             ...
# city_43        1
# city_107       1
# city_127       1
# city_62        1
# city_129       1
# Name: city, Length: 115, dtype: int64
# ____________________________________________________________________________________________________
# gender
# Male      8366
# Female     834
# Other       87
# Name: gender, dtype: int64
# ____________________________________________________________________________________________________
# relevent_experience
# Has relevent experience    8133
# No relevent experience     1154
# Name: relevent_experience, dtype: int64
# ____________________________________________________________________________________________________
# enrolled_university
# no_enrollment       7905
# Full time course     816
# Part time course     566
# Name: enrolled_university, dtype: int64
# ____________________________________________________________________________________________________
# education_level
# Graduate    6418
# Masters     2585
# Phd          284
# Name: education_level, dtype: int64
# ____________________________________________________________________________________________________
# major_discipline
# STEM               8228
# Humanities          425
# Other               187
# Business Degree     187
# Arts                142
# No Major            118
# Name: major_discipline, dtype: int64
# ____________________________________________________________________________________________________
# experience
# >20    2107
# 10      566
# 5       557
# 9       547
# 6       526
# 7       484
# 4       475
# 15      419
# 3       402
# 11      401
# 8       392
# 14      356
# 16      337
# 12      302
# 2       280
# 13      254
# 17      224
# 19      188
# 18      185
# 1       105
# 20       94
# <1       86
# Name: experience, dtype: int64
# ____________________________________________________________________________________________________
# company_size
# 50-99                  2047
# 100-500                1904
# 10000+                 1491
# 1000-4999               985
# 1949-10-01 00:00:00     958
# <10                     879
# 500-999                 609
# 5000-9999               414
# Name: company_size, dtype: int64
# ____________________________________________________________________________________________________
# company_type
# Pvt Ltd                7018
# Funded Startup          815
# Public Sector           622
# Early Stage Startup     382
# NGO                     375
# Other                    75
# Name: company_type, dtype: int64
# ____________________________________________________________________________________________________
# last_new_job
# 1        3897
# >4       2118
# 2        1629
# 3         648
# 4         643
# never     352
# Name: last_new_job, dtype: int64
# ____________________________________________________________________________________________________

# %%
958/9287 *100   #percentage of rows that have the value '1949-10-01 00:00:00' as the company size
# Out:
# 10.315494777646173

# %%
# Replace '1949-10-01 00:00:00' by '10-49' in Company_Size column

# %%
df1['company_size']=df1['company_size'].astype(str)

# %%
df1['company_size']=df1['company_size'].replace('1949-10-01 00:00:00','10-49')

# %%
df1['company_size'].unique()
# Out:
# array(['100-500', '<10', '50-99', '5000-9999', '10000+', '1000-4999',
#        '500-999', '10-49'], dtype=object)

# %% [markdown]
# ### Check for Outliners

# %%
plt.boxplot(df1['training_hours'])
plt.title('Boxplot of Training Hours')
# Out:
# Text(0.5, 1.0, 'Boxplot of Training Hours')

# %%
Q1=df1['training_hours'].quantile(0.25)
Q3=df1['training_hours'].quantile(0.75)
IQR =Q3-Q1
Lower_whisker=Q1-(1.5*IQR)
Upper_whisker=Q3+(1.5*IQR)
print('Lower whisker is {}'.format(Lower_whisker))
print('Upper whisker is {}'.format(Upper_whisker))
# Out:
# Lower whisker is -74.5
# Upper whisker is 185.5

# %%
df1['training_hours'].max()
# Out:
# 336

# %%
df1['training_hours'].min()
# Out:
# 1

# %%
df1[df1['training_hours']>185.5]   #number of outliners
# Out:
#        enrollee_id      city  city_development_index gender  \
# 27            5634   city_76                   0.698   Male
# 39            7006  city_160                   0.920   Male
# 145          15830   city_16                   0.910   Male
# 156          26068   city_93                   0.865   Male
# 192          17811   city_64                   0.666   Male
# ...            ...       ...                     ...    ...
# 18237        24491  city_141                   0.763   Male
# 18255        31030   city_16                   0.910   Male
# 18267        24280   city_21                   0.624   Male
# 18321        17409   city_21                   0.624   Male
# 18345         2711   city_57                   0.866   Male
#
#            relevent_experience enrolled_university education_level  \
# 27     Has relevent experience       no_enrollment        Graduate
# 39     Has relevent experience       no_enrollment        Graduate
# 145    Has relevent experience       no_enrollment         Masters
# 156    Has relevent experience    Full time course        Graduate
# 192    Has relevent experience    Full time course        Graduate
# ...                        ...                 ...             ...
# 18237  Has relevent experience       no_enrollment        Graduate
# 18255  Has relevent experience       no_enrollment        Graduate
# 18267   No relevent experience       no_enrollment        Graduate
# 18321  Has relevent experience       no_enrollment         Masters
# 18345  Has relevent experience    Full time course        Graduate
#
#       major_discipline experience company_size         company_type  \
# 27                STEM         14          <10              Pvt Ltd
# 39                STEM         10      100-500              Pvt Ltd
# 145               STEM          7        50-99  Early Stage Startup
# 156               STEM          6       10000+              Pvt Ltd
# 192               STEM         14       10000+              Pvt Ltd
# ...                ...        ...          ...                  ...
# 18237             STEM         12        50-99              Pvt Ltd
# 18255             STEM         14        50-99       Funded Startup
# 18267             STEM          4      500-999              Pvt Ltd
# 18321             STEM         14        50-99       Funded Startup
# 18345             STEM          8          <10              Pvt Ltd
#
#       last_new_job  training_hours  target
# 27               2             298       0
# 39               2             262       0
# 145              2             206       0
# 156             >4             218       0
# 192              3             258       1
# ...            ...             ...     ...
# 18237            1             288       0
# 18255            1             256       0
# 18267            1             218       0
# 18321            1             224       0
# 18345            2             288       0
#
# [482 rows x 14 columns]

# %%
# 482 outliners in Training Hours

# %%
plt.figure(figsize=(10,10))
plt.boxplot(df1['city_development_index'])
plt.title('Boxplot of City Development Index')
# Out:
# Text(0.5, 1.0, 'Boxplot of City Development Index')

# %%
Q1=df1['city_development_index'].quantile(0.25)
Q3=df1['city_development_index'].quantile(0.75)
IQR =Q3-Q1
Lower_whisker=Q1-(1.5*IQR)
Upper_whisker=Q3+(1.5*IQR)

print('Lower whisker is {}'.format(Lower_whisker))
print('Upper whisker is {}'.format(Upper_whisker))
# Out:
# Lower whisker is 0.7374999999999998
# Upper whisker is 1.0295

# %%
df1['city_development_index'].min()
# Out:
# 0.448

# %%
df1['city_development_index'].max()
# Out:
# 0.949

# %%
df1[df1['city_development_index']<0.7374999999999998]   #checking the number of outliners
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 0            23798  city_149                   0.689    Male
# 3            18527   city_64                   0.666    Male
# 5            13342   city_21                   0.624  Female
# 6            11746   city_21                   0.624    Male
# 13           33356   city_90                   0.698    Male
# ...            ...       ...                     ...     ...
# 18307        19429   city_21                   0.624    Male
# 18315        30649   city_70                   0.698  Female
# 18321        17409   city_21                   0.624    Male
# 18324        33152   city_21                   0.624    Male
# 18339        24134   city_21                   0.624    Male
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 3      Has relevent experience       no_enrollment        Graduate
# 5      Has relevent experience       no_enrollment        Graduate
# 6      Has relevent experience       no_enrollment        Graduate
# 13     Has relevent experience       no_enrollment        Graduate
# ...                        ...                 ...             ...
# 18307  Has relevent experience       no_enrollment        Graduate
# 18315  Has relevent experience    Full time course        Graduate
# 18321  Has relevent experience       no_enrollment         Masters
# 18324  Has relevent experience       no_enrollment         Masters
# 18339  Has relevent experience    Full time course         Masters
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM          3      100-500         Pvt Ltd            1
# 3                 STEM         14        50-99         Pvt Ltd            1
# 5                Other          8    5000-9999         Pvt Ltd            2
# 6                 STEM          6       10000+         Pvt Ltd            3
# 13                STEM        >20      100-500         Pvt Ltd           >4
# ...                ...        ...          ...             ...          ...
# 18307             STEM          7       10000+         Pvt Ltd        never
# 18315             STEM          9        50-99         Pvt Ltd            1
# 18321             STEM         14        50-99  Funded Startup            1
# 18324             STEM          3      100-500         Pvt Ltd            1
# 18339             STEM          9      100-500         Pvt Ltd            4
#
#        training_hours  target
# 0                 106       0
# 3                  26       0
# 5                  34       0
# 6                  23       1
# 13                 51       0
# ...               ...     ...
# 18307               6       0
# 18315              95       1
# 18321             224       0
# 18324              11       0
# 18339              98       0
#
# [1295 rows x 14 columns]

# %%
# 1295 outliners in City Development Index

# %% [markdown]
# ### Outliner Treatment

# %%
outliners=df1[(df['city_development_index']<0.7374999999999998) | (df1['training_hours']>185.5)]
outliners
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 0            23798  city_149                   0.689    Male
# 3            18527   city_64                   0.666    Male
# 5            13342   city_21                   0.624  Female
# 6            11746   city_21                   0.624    Male
# 13           33356   city_90                   0.698    Male
# ...            ...       ...                     ...     ...
# 18315        30649   city_70                   0.698  Female
# 18321        17409   city_21                   0.624    Male
# 18324        33152   city_21                   0.624    Male
# 18339        24134   city_21                   0.624    Male
# 18345         2711   city_57                   0.866    Male
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 3      Has relevent experience       no_enrollment        Graduate
# 5      Has relevent experience       no_enrollment        Graduate
# 6      Has relevent experience       no_enrollment        Graduate
# 13     Has relevent experience       no_enrollment        Graduate
# ...                        ...                 ...             ...
# 18315  Has relevent experience    Full time course        Graduate
# 18321  Has relevent experience       no_enrollment         Masters
# 18324  Has relevent experience       no_enrollment         Masters
# 18339  Has relevent experience    Full time course         Masters
# 18345  Has relevent experience    Full time course        Graduate
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM          3      100-500         Pvt Ltd            1
# 3                 STEM         14        50-99         Pvt Ltd            1
# 5                Other          8    5000-9999         Pvt Ltd            2
# 6                 STEM          6       10000+         Pvt Ltd            3
# 13                STEM        >20      100-500         Pvt Ltd           >4
# ...                ...        ...          ...             ...          ...
# 18315             STEM          9        50-99         Pvt Ltd            1
# 18321             STEM         14        50-99  Funded Startup            1
# 18324             STEM          3      100-500         Pvt Ltd            1
# 18339             STEM          9      100-500         Pvt Ltd            4
# 18345             STEM          8          <10         Pvt Ltd            2
#
#        training_hours  target
# 0                 106       0
# 3                  26       0
# 5                  34       0
# 6                  23       1
# 13                 51       0
# ...               ...     ...
# 18315              95       1
# 18321             224       0
# 18324              11       0
# 18339              98       0
# 18345             288       0
#
# [1701 rows x 14 columns]

# %%
# 1701 rows with outliners

# %%
mask1=df1['city_development_index']<0.7374999999999998  
df1.loc[mask1,'city_development_index']=0.7374999999999998    #capping outliners
df1
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 0            23798  city_149                  0.7375    Male
# 1            29166   city_83                  0.9230    Male
# 3            18527   city_64                  0.7375    Male
# 5            13342   city_21                  0.7375  Female
# 6            11746   city_21                  0.7375    Male
# ...            ...       ...                     ...     ...
# 18354        25366  city_103                  0.9200    Male
# 18355        25545  city_160                  0.9200    Male
# 18356        11514  city_114                  0.9260    Male
# 18357         1689   city_75                  0.9390    Male
# 18358         5995  city_105                  0.7940  Female
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1      Has relevent experience       no_enrollment        Graduate
# 3      Has relevent experience       no_enrollment        Graduate
# 5      Has relevent experience       no_enrollment        Graduate
# 6      Has relevent experience       no_enrollment        Graduate
# ...                        ...                 ...             ...
# 18354  Has relevent experience    Full time course        Graduate
# 18355   No relevent experience       no_enrollment        Graduate
# 18356  Has relevent experience       no_enrollment         Masters
# 18357  Has relevent experience       no_enrollment        Graduate
# 18358  Has relevent experience       no_enrollment        Graduate
#
#       major_discipline experience         company_size    company_type  \
# 0                 STEM          3              100-500         Pvt Ltd
# 1                 STEM         14                  <10  Funded Startup
# 3                 STEM         14                50-99         Pvt Ltd
# 5                Other          8            5000-9999         Pvt Ltd
# 6                 STEM          6               10000+         Pvt Ltd
# ...                ...        ...                  ...             ...
# 18354             STEM          5                  <10         Pvt Ltd
# 18355       Humanities         15                50-99         Pvt Ltd
# 18356             STEM         11                50-99         Pvt Ltd
# 18357             STEM        >20  1949-10-01 00:00:00         Pvt Ltd
# 18358             STEM        >20              100-500         Pvt Ltd
#
#       last_new_job  training_hours  target
# 0                1             106       0
# 1                1              69       0
# 3                1              26       0
# 5                2              34       0
# 6                3              23       1
# ...            ...             ...     ...
# 18354            1              71       0
# 18355            1             160       0
# 18356            3              18       0
# 18357            3              41       0
# 18358            2              84       0
#
# [9287 rows x 14 columns]

# %%
mask2 = df1['training_hours']>185.5   
df1.loc[mask2,'training_hours']=185.5   #capping outliners
df1
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 0            23798  city_149                  0.7375    Male
# 1            29166   city_83                  0.9230    Male
# 3            18527   city_64                  0.7375    Male
# 5            13342   city_21                  0.7375  Female
# 6            11746   city_21                  0.7375    Male
# ...            ...       ...                     ...     ...
# 18354        25366  city_103                  0.9200    Male
# 18355        25545  city_160                  0.9200    Male
# 18356        11514  city_114                  0.9260    Male
# 18357         1689   city_75                  0.9390    Male
# 18358         5995  city_105                  0.7940  Female
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1      Has relevent experience       no_enrollment        Graduate
# 3      Has relevent experience       no_enrollment        Graduate
# 5      Has relevent experience       no_enrollment        Graduate
# 6      Has relevent experience       no_enrollment        Graduate
# ...                        ...                 ...             ...
# 18354  Has relevent experience    Full time course        Graduate
# 18355   No relevent experience       no_enrollment        Graduate
# 18356  Has relevent experience       no_enrollment         Masters
# 18357  Has relevent experience       no_enrollment        Graduate
# 18358  Has relevent experience       no_enrollment        Graduate
#
#       major_discipline experience         company_size    company_type  \
# 0                 STEM          3              100-500         Pvt Ltd
# 1                 STEM         14                  <10  Funded Startup
# 3                 STEM         14                50-99         Pvt Ltd
# 5                Other          8            5000-9999         Pvt Ltd
# 6                 STEM          6               10000+         Pvt Ltd
# ...                ...        ...                  ...             ...
# 18354             STEM          5                  <10         Pvt Ltd
# 18355       Humanities         15                50-99         Pvt Ltd
# 18356             STEM         11                50-99         Pvt Ltd
# 18357             STEM        >20  1949-10-01 00:00:00         Pvt Ltd
# 18358             STEM        >20              100-500         Pvt Ltd
#
#       last_new_job  training_hours  target
# 0                1           106.0       0
# 1                1            69.0       0
# 3                1            26.0       0
# 5                2            34.0       0
# 6                3            23.0       1
# ...            ...             ...     ...
# 18354            1            71.0       0
# 18355            1           160.0       0
# 18356            3            18.0       0
# 18357            3            41.0       0
# 18358            2            84.0       0
#
# [9287 rows x 14 columns]

# %%
df1['training_hours'].max()
# Out:
# 185.5

# %%
df1['city_development_index'].min()
# Out:
# 0.7374999999999998

# %%
df1.boxplot('training_hours')
# Out:
# <AxesSubplot:>

# %%
df1.boxplot('city_development_index')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##  Data Analysis

# %% [markdown]
# ### Univariate Analysis

# %%
df1.describe()   #exploring the 5-point summarynumerical variables
# Out:
#         enrollee_id  city_development_index  training_hours       target
# count   9287.000000             9287.000000     9287.000000  9287.000000
# mean   16786.807042                0.874844       61.829116     0.106708
# std     9989.674531                0.070312       50.270900     0.308759
# min        2.000000                0.737500        1.000000     0.000000
# 25%     8076.500000                0.847000       23.000000     0.000000
# 50%    16674.000000                0.913000       47.000000     0.000000
# 75%    25926.000000                0.920000       88.000000     0.000000
# max    33380.000000                0.949000      185.500000     1.000000

# %%
#drawing a histogram to understand the distribution of Training hours
plt.figure(figsize=(20,5))
sns.histplot(df1['training_hours'],kde=True) 
plt.title('Histogram of Training Hours',size=25)
plt.xticks(size=15)
plt.yticks(size=15)
plt.xlabel("Training Hours",size=15)
plt.ylabel("Frequency",size=15)
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.title('Histogram of City Development Index',size=25)
sns.histplot(df1['city_development_index'],kde=True) 
plt.xticks(size=15)
plt.yticks([0,500,1000,1500,2000,2500,3000,3500,4000],size=15)
plt.xlabel("City Development Index",size=15)
plt.ylabel("Frequency",size=15)
plt.show()

# %%
df1.describe(include=object)  #exploring categorical variables
# Out:
#             city gender      relevent_experience enrolled_university  \
# count       9287   9287                     9287                9287
# unique       115      3                        2                   3
# top     city_103   Male  Has relevent experience       no_enrollment
# freq        2685   8366                     8133                7905
#
#        education_level major_discipline experience company_size company_type  \
# count             9287             9287       9287         9287         9287
# unique               3                6         22            8            6
# top           Graduate             STEM        >20        50-99      Pvt Ltd
# freq              6418             8228       2107         2047         7018
#
#         last_new_job
# count           9287
# unique             6
# top                1
# freq            3897

# %% [markdown]
# ### Bivariate Analysis

# %%
df1[['training_hours','city_development_index']].corr()   # finding the correlation matrix for numerical variables
# Out:
#                         training_hours  city_development_index
# training_hours                 1.00000                -0.00509
# city_development_index        -0.00509                 1.00000

# %%
# City Development Index and Training Hours have a negative and weak correlation

# %%
sns.scatterplot(df1['training_hours'],df1['city_development_index'])   #drawing a scatterplot to visualize the correlation
# Out:
# <AxesSubplot:xlabel='training_hours', ylabel='city_development_index'>

# %% [markdown]
# ### There exists almost zero correlation between the variables.A change in Training hours is not considerably associated with a  change in City development index.

# %% [markdown]
# ### Q1 Are there any prominent cities where enrollees are more inclined to look for new job?

# %%
df2=df1[df1.loc[:,'target']==1]   #filtering out only those records which have enrollees looking for a new job
df2.head()
# Out:
#     enrollee_id      city  city_development_index  gender  \
# 6         11746   city_21                  0.7375    Male
# 51        14257   city_21                  0.7375    Male
# 65        26681  city_103                  0.9200    Male
# 74        28674  city_160                  0.9200    Male
# 81        11934  city_160                  0.9200  Female
#
#         relevent_experience enrolled_university education_level  \
# 6   Has relevent experience       no_enrollment        Graduate
# 51   No relevent experience    Full time course        Graduate
# 65  Has relevent experience       no_enrollment        Graduate
# 74  Has relevent experience       no_enrollment        Graduate
# 81  Has relevent experience       no_enrollment        Graduate
#
#    major_discipline experience         company_size company_type last_new_job  \
# 6              STEM          6               10000+      Pvt Ltd            3
# 51             STEM         13  1949-10-01 00:00:00          NGO            1
# 65  Business Degree        >20               10000+      Pvt Ltd            3
# 74       Humanities        >20                50-99      Pvt Ltd           >4
# 81             STEM         10  1949-10-01 00:00:00      Pvt Ltd            4
#
#     training_hours  target
# 6             23.0       1
# 51            21.0       1
# 65             8.0       1
# 74            33.0       1
# 81           101.0       1

# %%
plt.figure(figsize=(20,50))
a=sns.countplot(data=df2,y='city',order=df2['city'].value_counts().index)
#df2.city.value_counts().plot(kind='barh',color='orange')
plt.title("City wise Comparison of Job-Seeking Enrolees",size=20)
a.set_ylabel("City Code",size=20)
# Out:
# Text(0, 0.5, 'City Code')

# %%
df2['city'].value_counts(normalize=True).sort_values(ascending=False)
# Out:
# city_103    0.265388
# city_21     0.188698
# city_16     0.069627
# city_114    0.063572
# city_160    0.034309
#               ...
# city_141    0.001009
# city_69     0.001009
# city_175    0.001009
# city_45     0.001009
# city_81     0.001009
# Name: city, Length: 89, dtype: float64

# %% [markdown]
# ### The top 5 cities from which job-seeking enrolees come from are city_103,city_16 ,city_114,city_21 and city_160. In fact 26.5% of them are from city_103.

# %% [markdown]
# ### Q2 Are enrolees with lower years of experience looking for a new job?

# %%
plt.figure(figsize=(20,10))
b = sns.countplot(data=df2,x='experience',order=df2['experience'].value_counts().index)
plt.title("Experience wise Comparison of Job-Seeking Enrolees",size=20)
b.set_ylabel("Count",size=15)
b.set_xlabel("Years of Experience",size=15)
plt.show()

# %%
df2['experience'].value_counts(normalize=True)
# Out:
# >20    0.161453
# 5      0.072654
# 7      0.067608
# 4      0.066599
# 6      0.065590
# 3      0.060545
# 10     0.059536
# 9      0.059536
# 15     0.043391
# 2      0.039354
# 8      0.039354
# 14     0.037336
# 11     0.036327
# 1      0.033300
# 13     0.029263
# 16     0.027245
# <1     0.026236
# 12     0.022200
# 17     0.022200
# 19     0.011100
# 18     0.011100
# 20     0.008073
# Name: experience, dtype: float64

# %% [markdown]
# ### No. Highest number of job-seeking enrolees have more than 20 years of experience. Enrolees with fewer years of experience are not the prominent job-seekers.

# %% [markdown]
# ### Q3 Do enrolees looking for a new job spend a high time in training?

# %%
plt.figure(figsize=(20,10))
plt.title("Training Hours of Job-Seeking Enrolees",size=20)
c=sns.histplot(df2['training_hours'],bins=10,kde=True)
c.set_xlabel("Training Hours",size=15)
c.set_ylabel("Count",size=15)
plt.show()

# %%
df2['training_hours'].describe()
# Out:
# count    991.000000
# mean      60.499495
# std       51.098798
# min        1.000000
# 25%       22.000000
# 50%       45.000000
# 75%       84.500000
# max      185.500000
# Name: training_hours, dtype: float64

# %% [markdown]
# ### The average time job-seeking employees spend on attending training is 60.5 hours.
# ### 75% of them spend less than or equal to 84.5 hours in training.So enrolees looking for jobs do not spend high time in tarining.

# %% [markdown]
# ### Q4 Do enrolees looking for new jobs frequently change their jobs or spend considerable time in their last job?

# %%
df2['last_new_job'].value_counts(normalize=True)
# Out:
# 1        0.404642
# 2        0.196771
# >4       0.189707
# 4        0.082745
# 3        0.079717
# never    0.046418
# Name: last_new_job, dtype: float64

# %%
plt.figure(figsize=(20,10))
plt.title("Company Type of Job-Seeking Enrolees",size=20)
c=sns.countplot(df2['last_new_job'],order=df2['last_new_job'].value_counts().index)
c.set_xlabel("Number of Years between Previous and Current Job",size=15)
plt.xticks(size=12)
plt.yticks(size=12)
c.set_ylabel("Count",size=15)
plt.show()

# %% [markdown]
# ###  40.5% of enrolees who are seeking a job change have changed their job frequently as the number of years between their previous job and current job is only 1 year.However, 19% of job-seeking enrolees are looking for a new job after spending a considerable time of more than 4 years in their last job.

# %% [markdown]
# ### Q5 Are private sector employees more inclined towards finding new jobs?

# %%
plt.figure(figsize=(20,10))
plt.title("Company Type of Job-Seeking Enrolees",size=20)
c=sns.countplot(df2['company_type'],order=df2['company_type'].value_counts(ascending=False).index)
c.set_xlabel("Company Type",size=15)
plt.xticks(size=12)
plt.yticks(size=12)
c.set_ylabel("Count",size=15)
plt.show()

# %%
df2['company_type'].value_counts(normalize=True)
# Out:
# Pvt Ltd                0.738648
# Public Sector          0.089808
# Funded Startup         0.075681
# NGO                    0.045409
# Early Stage Startup    0.039354
# Other                  0.011100
# Name: company_type, dtype: float64

# %% [markdown]
# ### Yes,private sector employees are more inclined to find new jobs.
# ### 74% of the job-seeking enrolees are employed in private sector.

# %% [markdown]
# ### Q6 Are males more inclined to looking for a new job as compared to females?

# %%
plt.figure(figsize=(30,5))
a=df2['gender'].value_counts()
plt.pie(a,labels=a.index,autopct='%0.1f%%',radius=1.5)   #to create a pie chart
plt.title("Gender Comparison of Job-Seekers",pad=40)   #to position the title above the pie chart
plt.show()

# %% [markdown]
# ### Yes, 88.9% of the job-seeking enrolees are males

# %% [markdown]
# ### Q7 Are non-STEM background enrolees are inclined for a new job?

# %%
df2['major_discipline'].value_counts(normalize=True)
# Out:
# STEM               0.906155
# Humanities         0.043391
# Business Degree    0.018163
# Other              0.013118
# Arts               0.010091
# No Major           0.009082
# Name: major_discipline, dtype: float64

# %%
plt.figure(figsize=(20,10))
plt.title("Major Discipline of Job-Seeking Enrolees",size=20)
c=sns.countplot(df2['major_discipline'],order=df2['major_discipline'].value_counts(ascending=False).index)
c.set_xlabel("Major Discipline",size=15)
plt.xticks(size=12)
plt.yticks(size=12)
c.set_ylabel("Count",size=15)
plt.show()

# %% [markdown]
# ### No. 91% of enrolees who are looking for new jobs have a STEM background.

# %% [markdown]
# ### Q8  Are there other specific insights that can help us understand the drivers for job change?

# %%
df2.columns
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'last_new_job', 'training_hours', 'target'],
#       dtype='object')

# %%
df2[[ 'city_development_index', 
       'relevent_experience', 'enrolled_university', 'education_level',
        'company_size','target'
        ]]
# Out:
#        city_development_index      relevent_experience enrolled_university  \
# 6                      0.7375  Has relevent experience       no_enrollment
# 51                     0.7375   No relevent experience    Full time course
# 65                     0.9200  Has relevent experience       no_enrollment
# 74                     0.9200  Has relevent experience       no_enrollment
# 81                     0.9200  Has relevent experience       no_enrollment
# ...                       ...                      ...                 ...
# 18200                  0.7375  Has relevent experience       no_enrollment
# 18262                  0.7375  Has relevent experience       no_enrollment
# 18293                  0.9200   No relevent experience       no_enrollment
# 18315                  0.7375  Has relevent experience    Full time course
# 18329                  0.8970  Has relevent experience       no_enrollment
#
#       education_level         company_size  target
# 6            Graduate               10000+       1
# 51           Graduate  1949-10-01 00:00:00       1
# 65           Graduate               10000+       1
# 74           Graduate                50-99       1
# 81           Graduate  1949-10-01 00:00:00       1
# ...               ...                  ...     ...
# 18200        Graduate                50-99       1
# 18262        Graduate  1949-10-01 00:00:00       1
# 18293        Graduate              100-500       1
# 18315        Graduate                50-99       1
# 18329         Masters  1949-10-01 00:00:00       1
#
# [991 rows x 6 columns]

# %% [markdown]
# ### 8a What is the education level of enrolees who desire a job change?

# %%
plt.figure(figsize=(20,10))
plt.title("Education Level of Job-Seeking Enrolees",size=20)
c=sns.countplot(y=df2['education_level'],order=df2['education_level'].value_counts(ascending=False).index)
c.set_ylabel("Highest Education",size=15)
plt.xticks(size=12)
plt.yticks(size=12)
c.set_xlabel("Count",size=15)
plt.show()

# %%
df2['education_level'].value_counts(normalize=True)
# Out:
# Graduate    0.717457
# Masters     0.248234
# Phd         0.034309
# Name: education_level, dtype: float64

# %%
### 72% of enrolees who are actively seeking a job change are of Graduate education level.

# %% [markdown]
# ### 8b Do the job-seekers have relevant experience?

# %%
plt.figure(figsize=(30,5))
plt.title("Comparison of Relevant Experience of Job-Seekers",pad=40)  ##to ensure title is above the pie chart
a=df2['relevent_experience'].value_counts()
plt.pie(a,labels=a.index,autopct='%0.1f%%',radius=1.5) #creating a pie chart
plt.show()

# %% [markdown]
# ### 83.6% of active job-seeking trainees have relevant experience in the field

# %% [markdown]
# ### 8c What type of university courses are they enrolled in?

# %%
plt.figure(figsize=(20,10))
plt.title("Enrollment in University Courses",size=20)
c=sns.countplot(x=df2['enrolled_university'],order=df2['enrolled_university'].value_counts(ascending=False).index)
c.set_xlabel("Type of Enrolment",size=15)
plt.xticks(size=12)
plt.yticks(size=12)
c.set_ylabel("Count",size=15)
plt.show()

# %%
df2['enrolled_university'].value_counts(normalize=True)
# Out:
# no_enrollment       0.791120
# Full time course    0.140262
# Part time course    0.068618
# Name: enrolled_university, dtype: float64

# %% [markdown]
# ### 79% of active job seekers are not enrolled in any University courses

# %% [markdown]
# ### 8d Does city development index act as a driving factor for job change?

# %%
plt.figure(figsize=(20,10))
plt.title("Comparison of City Development Indices of Job-Seeking Enrolees",size=20)
c=sns.histplot(df2['city_development_index'],bins=10,kde=True)
c.set_xlabel("City Development Index",size=15)
c.set_ylabel("Count",size=15)
plt.show()

# %%
df2['city_development_index'].describe()
# Out:
# count    991.000000
# mean       0.848653
# std        0.082746
# min        0.737500
# 25%        0.737500
# 50%        0.903000
# 75%        0.920000
# max        0.949000
# Name: city_development_index, dtype: float64

# %%
df2['city_development_index'].mode()
# Out:
# 0    0.92
# Name: city_development_index, dtype: float64

# %% [markdown]
# ### Average city development index of the cities of job-seeking enrolees in 0.848. 75%  of job-seekers are from cities that have a city development index of 0.92 or less.

# %% [markdown]
# ### 8e What is the number of employees in the current company of the job-seeking enrolees?

# %%
df2['company_size'].value_counts()
# Out:
# 50-99                  202
# 100-500                201
# 10000+                 180
# 1949-10-01 00:00:00    114
# 1000-4999              104
# <10                     82
# 500-999                 63
# 5000-9999               45
# Name: company_size, dtype: int64

# %%
df2[df2['company_size']=='Oct-49']
# Out:
# Empty DataFrame
# Columns: [enrollee_id, city, city_development_index, gender, relevent_experience, enrolled_university, education_level, major_discipline, experience, company_size, company_type, last_new_job, training_hours, target]
# Index: []

# %% [markdown]
# ### Thank you!
